# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2}

# use some dictionary method such that this cell prints True


print(my_dict == {})

# %%
my_dict_1 = {'a': 1, 'b': 2}

# create a new variable my_dict_2 which is a copy of my_dict_1
# and then update it such that this cell prints True twice


print(my_dict_1 == {'a': 1, 'b': 2})
print(my_dict_2 == {'a': 1, 'b': 2, 'c': 3})

# %%
my_dict = {'a': 1, 'b': 17}

# create a new variable z (using the get method) such that this cell prints True


print(z == 17)

# %%
my_dict = {'a': 1, 'b': 2}

# create a new variable z such that this cell prints True


print(list(z) == [('a', 1), ('b', 2)])

# %%
my_dict = {'a': 1, 'b': 2}

# create a new variable z such that this cell prints True


print(list(z) == ['a', 'b'])

# %%
my_dict = {'a': 1, 'b': 2}

# create a new variable z such that this cell prints True


print(list(z) == [1, 2])

# %%
my_dict = {'a': 1, 'b': 2}

# use the pop method on my_dict such that this cell prints True


print(my_dict == {'b': 2})

# %%
my_dict = {'a': 1}

# use the update method on my_dict such that this cell prints True

print(my_dict == {'a': 1, 'b': 3})
