# %%
#### Introduction ####

# In this assignment we will be creating a Tic-Tac-Toe game.
# Some basic helper functions, structure, and comments have
# been provided to reduce difficulty and increase enjoyability.

# Specifications:
#     Games will be between User (human) and Computer
#     Computer alaways goes first
#     User plays 'O'; Computer plays 'X'
#     The application will only run a single game, until the game is over
#     User input will take the form of a number that represents a square
#       (similar to a number pad; see the 3x3 matrix below)

# Note: cells must be ran to be loaded into memory;
#       i.e. if you want to use the contents of a
#       cell, that cell must be ran (each time the
#       kernel is loaded/restarted).

## Matrices Review ##

# a 3x3 matrix in numbered form
[
    [0, 1, 2],
    [3, 4, 5],
    [6, 7, 8]
]
# numbered from left to right, top to bottom
# this is a list, containing 3 lists
# to access the first row [0, 1, 2] we would index at [0]
# to access the second row [3, 4, 5] we would index at [1]
# to access the number 0, we would index at [0][0]
# to access the number 3, we would index at [1][0]
# to access the number 7, we would index at [2][1]


# that same matrix, assigned to the variable "mat_num"
mat_num = [[0, 1, 2],
           [3, 4, 5],
           [6, 7, 8]]

# to access number 7:
mat_num[2][1]


# a 3x3 matrix in (i, j) notation
[
    [(0, 0), (0, 1), (0, 2),],
    [(1, 0), (1, 1), (1, 2),],
    [(2, 0), (2, 1), (2, 2),]
]
# the i is the row (top to bottom)
# the j is the column (left to right)

[#    col 1   col 2   col 3
    [(0, 0), (0, 1), (0, 2),],  # row 0
    [(1, 0), (1, 1), (1, 2),],  # row 1
    [(2, 0), (2, 1), (2, 2),]   # row 2
]

# that same matrix, assigned to the variable "mat_ij"
mat_ij = [
    [(0, 0), (0, 1), (0, 2),],
    [(1, 0), (1, 1), (1, 2),],
    [(2, 0), (2, 1), (2, 2),]
]


## helper functions ##

# to convert from the numbered matrix type [[0, 1, 2], ...],
# to the (i, j) matrix type, use "convert_int_to_ij()" below

# %%
# RUN THIS CELL TO LOAD THESE INTO MEMORY

# helper functions and globals

# the default, unplayed board
default = [[0, 1, 2],
           [3, 4, 5],
           [6, 7, 8]]


# convert int to (i, j)
def convert_int_to_ij(number):
    i = number // 3
    j = number % 3
    return (i, j)

# %%
##### Problem 01 #####
# This function accepts one parameter containing the board's current status
# and prints it out to the console.

# line by line solution:
# print each line, as it will appear in its final state
# hint: you can use a plain print('<string>') for each line
# hint: try to use an f-string to construct dynamic lines
# hint: you only need 3 different strings
def display_board(board):
    
    
    # a straightforward solution is to use a single for loop
    # If we iterated over board, what would the iterator variable be?
    # also, consider the use case of a dangling else statement

# %%
##### Problem 02 #####
# This function browses the board, builds and returns a list of all the free squares; 
# the list consists of tuples, while each tuple is a pair of row and column numbers.

def make_list_of_free_fields(board):
    # create an empty list nammed free_squares 
    
    # create a variable "length", of the board
    
    # iterate over the entire board, checking each element, 
    # while keeping track of the correct elements

# %%
##### Problem 03 #####
# This function accepts the board's current status, asks the user about their move, 
# checks the input, and updates the board according to the user's decision.

def enter_move(board):
    # get a list of avaliable moves
    
    # until the user provides a valid input,
    # continue to request user input
    
    # get user input and a list of playable moves
    
        
    # if user input is valid, update the board

# %%
##### Problem 04 #####
# This function analyzes the board's status in order to check if 
# the player using 'O's or 'X's has won the game, and returns True
# if the provided sign ('O' or 'X') satisfies a win condition

def victory_for(board, sign):
    # first, list every possible win condition (hint, it is less than 10) by coding
    # a check (below) for every possible win condition (note: this isn't elegant)
    # there should be 3 checks for horizontal...
    
    # horizontals
    

    # verticals

        
    # diagonals

# %%
##### Problem 05 #####
# This function chooses the computer's move and updates the board.
# Notify the player of the computers move.

# import the choice method from the random module
# example: from <module> import <method>


def draw_move(board):
    
    # get list of free fields
    
    # choose from one of the free field
    # TODO: unless its the first move, then take the center spot
    
    # notify the user and update the board

# %%
##### Problem 06 #####
# Code the application

# initialize a default (empty) board
board = 

# play the game until a player wins
# check for end conditions (vicotry or tie)
while True:
    # have the computer draw a move, if one is available
    # How could we check to ensure a move is available?
    # What do we do if no moves are available?
    
    
    # if the board has changed state, check for a victory condition
    
    
    
    # have the user enter their move, if one is available
    
    # if the board has changed state, check for a victory condition
    # What do we do upon reaching a victory condition?
