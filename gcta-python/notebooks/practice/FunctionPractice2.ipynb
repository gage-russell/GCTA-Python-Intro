# %%
def my_function(a, b=True):
    if b:
        if len(a) > 2:
            return sum(a)
        else:
            return 0
    else:
        return 1
    
foo = my_function([1,2,3], False)

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a, b=True):
    if b:
        if len(a) > 2:
            return sum(a)
        else:
            return 0
    else:
        return 1
    
foo = my_function([1,2,3], True)

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a, b=True):
    if b:
        if len(a) > 2:
            return sum(a)
        else:
            return 0
    else:
        return 1
    
foo = my_function([1,2,3], b=False)

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a, b=True):
    if b:
        if len(a) > 2:
            return sum(a)
        else:
            return 0
    else:
        return 1
    
foo = my_function([1,2])

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a, b=True):
    if b:
        if len(a) > 2:
            return sum(a)
        else:
            return 0
    else:
        return 1
    
foo = my_function(a=[1, 3, 5])

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a='abc'):
    c = []
    if 'b' in a:
        for i in a:
            c.append(i)
            
    return c
    
foo = my_function()

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a='acdc'):
    c = []
    if 'b' in a:
        for i in a:
            c.append(i)
            
    return c
    
foo = my_function()

# create a variable z such that this cell prints True


print(foo == z)

# %%
def my_function(a, b, c=1):
    if a > b and a > c:
        d = 0
    elif a == 10:
        d = 1
    else:
        d = 2
    return d

foo = my_function(a=2, b=4)

# create a variable z such that this cell prints True


print(foo == z)

# %%
my_dict = {
    'a': [2, 4],
    'b': [6, 8]
}

def my_function(d):
    num = 0
    
    for i in d.values():
        num += sum(i)
        
    return num

foo = my_function(my_dict)

# create a variable z such that this cell prints True


print(foo == z)

# %%
my_list = [2,4,6]

def my_function(m):
    thing = []
    
    for i in m:
        a = i%2 == 0
        thing.append(a)
        
    return thing

foo = my_function(my_list)


# create a variable z such that this cell prints True


print(foo == z)
