# %%
# conditional statements (reading)

# requirements:
#   operators
#   boolean operators
#   augmented assignments

# %%
# problem 0.0

'''
record time taken to complete this assignment

recall:

{keyword > if <} {expression_that_evaluates_to_a_boolean}{semicolon}
    {indented code}

for some_bool:
    # your code

for (2 > 0):
    print('foo')

''';

# %%
# problem 1

# make a prediction about the output
# and run the cell to test your prediction

if True:
    print('foo')

# %%
# problem 2

# make a prediction about the output
# and run the cell to test your prediction

if False:
    print('bar')

if True:
    print('baz')

# %%
# problem 3

if not False:
    print('nicht nicht')

if not True:
    print('nicht')

# %%
# problem 4

# make a prediction about the output
# and run the cell to test your prediction

if 3 > 1:
    print('this will print if: three is greater than one')

# %%
# problem 5

# make a prediction about the output
# and run the cell to test your prediction

variable_of_boolean_type = 6 > 5

if variable_of_boolean_type:
    print('this will print if: six is greater than five')

# %%
# problem 6

# make a prediction about the output
# and run the cell to test your prediction

var = 7 < 12

if var:
    print('this will print if: seven is less than 12')

# %%
# problem 7

# make a prediction about the output
# and run the cell to test your prediction

x = 2
y = 1

if x > y:
    print('this will print if: x is greater than y')

# %%
# problem 8

# make a prediction about the output
# and run the cell to test your prediction

x = 0
y = 4

if x > y:
    print('output_one; this will print if: x is greater than y')

if y > x:
    print('output_two; this will print if: y is greater than x')

print('this will print in either case; notice indentation')

# %%
# problem 9

# make a prediction about the output
# and run the cell to test your prediction

x = 1
y = 2
z = 3

if x > y:
    print('x > y')
else:
    print('x is not greater than y')

# %%
# problem 10

# make a prediction about the output
# and run the cell to test your prediction

x = 0
y = 1
z = 1

if x != 0:
    print('x != 0')
elif x >= 0:
    print('x == 0')
elif y == 1:
    print('y == 1')
elif y == z:
    print('y == z')
else:
    print('oi u cheeky lad')

print('gotcha...')

if y == z:
    print('y == z')

# %%
# problem 11

# make a prediction about the output
# and run the cell to test your prediction

x = 4
y = 9
z = 0

if y < z:
    print('y < z')
elif x < y:
    print('x < y')
else:
    print('neither preceeding statement is true')

# %%
# problem 12

# make a prediction about the output
# and run the cell to test your prediction

x = 3
y = 2
z = 7

if x <= y:
    print('x == y')
elif y == z:
    print('y == z')
else:
    print('neither preceeding statement is true')

# %%
# problem 13

# make a prediction about the output
# and run the cell to test your prediction

x = -1
y = 3
z = -4

if not x == y:
    print('not x == y')
elif y == 3:
    print('y == 3')
elif not y == z:
    print('not y == z')
else:
    print('neither preceeding statement is true')

# %%
# problem 14

# make a prediction about the output
# and run the cell to test your prediction

x = -2
y = 2
z = 1

if x == -2:
    print('not x == y')

if not y == 3:
    print('y == 3')
elif not y == z:
    print('not y == z')
else:
    print('else path taken')

# %%
# problem 15

# make a prediction about the output
# and run the cell to test your prediction

a = 7
b = 3

if a > b:
    print('output_one; this will print if: a is greater than b')

if b > a:
    print('output_two; this will print if: b is greater than a')
    
if not not True:
    print('\'tis truth')

if False:
    print('\'tis untruth')
    
if True:
    print('\'tis more truth')

print('this will print in either case; notice indentation')

# %%
# problem 16

# make a prediction about the output
# and run the cell to test your prediction

w = 0
x = 0
y = 5
z = 11

if w != x:
    print('w != x')
elif w > x:
    print('w > x')
elif w < x:
    print('w < x')
elif y > z:
    print('y > z')
elif z > w:
    print('z > w')
else:
    print('no preceeding statement is true')

# %%
# problem 17

# make a prediction about the output
# and run the cell to test your prediction

w = 1.0
x = 1
y = 5.5
z = 11

if w != x:
    print('w != x')
elif not w >= x:
    print('w > x')
elif w <= x:
    print('w < x')
elif y > z:
    print('y > z')
elif z > w:
    print('z > w')
else:
    print('no preceeding statement is true')

# %%
# problem 18

# make a prediction about the output
# and run the cell to test your prediction

men = 4
women = 4
students = 8
cars = 6

if men != women:
    print('men != women')
elif men > women:
    print('men > women')
elif men < women:
    print('men < women')
elif students > cars:
    print('students > cars')
elif cars > students:
    print('cars > students')
else:
    print('no preceeding statement is true')

# %%
# problem 19

# make a prediction about the output
# and run the cell to test your prediction

men = 6
women = 6
students = men + women
cars = 7

if men != women:
    print('men != women')
elif men > women:
    print('men > women')
elif men < women:
    print('men < women')
elif cars > students:
    print('students > cars')
elif students > cars:
    print('students > cars')
else:
    print('no preceeding statement is true')

print('bleep boop')

# %%
# conditional statements (reading) extended

# %%
# problem 20.0

# for the next 3 cells, we will be using:

a = 110
b = 12
c = 2
x = 8
y = 11
z = a - x

# you must run this cell to initalize these variables
print('values loaded into memory')

# %%
# problem 20.1

# using preceeding cell assignments
# make a prediction about the output
# and run the cell to test your prediction

# a = 110
# b = 12
# c = 2
# x = 8
# y = 11
# z = a - x

if 3 + z - 1 // c == 105:
    print('oof')
else:
    print('no oof')

# %%
# problem 20.2

# using preceeding cell assignments
# make a prediction about the output
# and run the cell to test your prediction

# a = 110
# b = 12
# c = 2
# x = 8
# y = 11
# z = a - x

if 3 + z - b + a + 1 // c == 205.5:
    print('owie_1')
elif not 3 + z - b + a + 1 // c == 203:
    print('owie_2')
else:
    print('no owie')

print('oi, we\'re doing things down here')

# %%
# problem 20.3

# using preceeding cell assignments
# make a prediction about the output
# and run the cell to test your prediction

if 3 + z - b + c ** c + a + 1 // c == 207:
    print('oof-owie')
else:
    print('no oof-owie')

print('goof')

# %%
# problem 21

# make a prediction about the output
# and run the cell to test your prediction

x = 3

if True:
    x = 0
else:
    x = 1
    
if x == 0:
    x = 2
    print('x is equal to:', x)

x = -1

# %%
# problem 22

# make a prediction about the output
# and run the cell to test your prediction

z = 'goo'

if z == 'goo':
    z += 'f'
else:
    z = 'good'
    
if z == 'good' and z == 'goof':
    print(z)

print(z + '_2')

# %%
# problem 23

# make a prediction about the output
# and run the cell to test your prediction

# NOTE: you don't need to worry about
# predicting this output exactly, only x

x = 'foo'

if not x == 'food':
    x += 'd'
else:
    x = 3
    x = 'inedible'
    
if x == 'inedible' or x == 'food':
    print('x has been assigned the \163\164\162\151\156\147:', x)  # ignore the \number\number...

x = 4

# %%
# problem 24

# make a prediction about the output
# and run the cell to test your prediction

if 0 == False:
    print('0 == ' + str(bool(0)) + '\n1 == ' + str(bool(1)))
else:
    print('else path')

# %%
# problem 25

# make a prediction about the output
# and run the cell to test your prediction

if 1 == True:
    print('0 == ' + str(bool(0)) + '\n1 == ' + str(bool(1)))
else:
    print('else path')

# %%
# problem 26

# make a prediction about the output
# and run the cell to test your prediction

if 0:
    print('if 0:')  

if 1:
    print('if 1:')

# %%
# problem 27

# make a prediction about the output
# and run the cell to test your prediction

if 0 == False:
    print('0 == ' + str(bool(0)) + '\n1 == ' + str(bool(1)))
if 1 == False:
    print('0 == ' + str(bool(0)) + '\n1 == ' + str(bool(1)))

# %%
# problem 28

# make a prediction about the output
# and run the cell to test your prediction

if 1.0 >= 1:
    print('1.0 >= 1')
else:
    print('else path 1')

if 1.0 <= 1:
    print('1.0 <= 1')
elif  1.0 == 1:
    print('1.0 == 1')
else:
    print('else path 2')

if 1.0 == 1:
    print('1.0 == 1')
else:
    print('else path 3')

# %%
# run this cell and answer the question

from IPython.display import HTML
prompt = 'Approximately how long did this assignment take you to complete? '
usr_answer = input(prompt)
display(HTML(f'<font size="+3">{usr_answer}</font>'))
