# %%
# Basic Data Types

# provide the Python ID of the type:
# int, float, bool, str, NoneType

# %%
# example problem

# identify the data type of id_this
id_this = 1

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 1
# identify the data type of id_this
id_this = 1.0

# assign your answer to data_type
data_type = float

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 2
# identify the data type of id_this
id_this = False

# assign your answer to data_type
data_type = bool

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 3
# identify the data type of id_this
id_this = -31337

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 4
# identify the data type of id_this
id_this = 0.0

# assign your answer to data_type
data_type = float

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 5
# identify the data type of id_this
id_this = '3.14159265358979323846264338327950'

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 6
# identify the data type of id_this
id_this = '\n'

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 7
# identify the data type of id_this
id_this = 0

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 8
# identify the data type of id_this
id_this = True

# assign your answer to data_type
data_type = bool

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 9
# identify the data type of id_this
id_this = 'float'

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 10
# identify the data type of id_this
id_this = -0.0

# assign your answer to data_type
data_type = float

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 11
# identify the data type of id_this
id_this = "Hello, World!"

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 12
# identify the data type of id_this
id_this = 999999999999999999999999

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 13
# identify the data type of id_this
id_this = "1 + 1 = 3"

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 14
# identify the data type of id_this
id_this = -0

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 15
# identify the data type of id_this
id_this = -777.321

# assign your answer to data_type
data_type = float

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 16
# identify the data type of id_this
id_this = 'boolean'

# assign your answer to data_type
data_type = str

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 17
# identify the data type of id_this
id_this = 6

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 18
# identify the data type of id_this
id_this = 3.14

# assign your answer to data_type
data_type = float

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# problem 19
NoneType = type(None)  # NoneType was reintroduced in Python 3.10

# identify the data type of id_this
id_this = None

# assign your answer to data_type
data_type = NoneType

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True

# %%
# Basic Data Types Extended

# %%
# bonus problem 1
# identify the data type of id_this
id_this = 999_999_999_999_999_999_999_999

# assign your answer to data_type
data_type = int

# run the cell to check your answer
print(type(id_this) == data_type)
# Out:
# True
