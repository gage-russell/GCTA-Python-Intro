# %%
# %run ./{load}.ipynb
# Out:
# Helper functions successfully loaded!

# %%
# Basic Data Types

# %%
# identify the data type of id_this
id_this = 1.0

# assign your answer to data_type
data_type = 'float'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = False

# assign your answer to data_type
data_type = 'bool'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = -31337

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 0.0

# assign your answer to data_type
data_type = 'float'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = '3.14159265358979323846264338327950'

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = '\n'

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 0

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = True

# assign your answer to data_type
data_type = 'bool'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = None

# assign your answer to data_type
data_type = 'NoneType'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 'float'

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = -0.0

# assign your answer to data_type
data_type = 'float'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = "Hello, World!"

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 999999999999999999999999

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = "1 + 1 = 3"

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = -0

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = -0

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 'boolean'

# assign your answer to data_type
data_type = 'str'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 6

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# identify the data type of id_this
id_this = 3.14

# assign your answer to data_type
data_type = 'float'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# Basic Data Types Extended

# %%
# identify the data type of id_this
id_this = 999_999_999_999_999_999_999_999

# assign your answer to data_type
data_type = 'int'

# run the cell to check your answer
print(id_data_type(id_this, data_type))
# Out:
# True

# %%
# todo:
#   review None type (maybe move to extended)
#   ways to expand (case?; type type?;)
