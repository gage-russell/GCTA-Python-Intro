# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_string = 'hello world'

# create a new variable foo such that this cell prints True
# use a method on my_string to create foo

foo = my_string.capitalize()

print(foo == 'Hello world')
# Out:
# True

# %%
my_string = 'aabc'

# create a new variable foo such that this cell prints True
# use the count method on my_string to create foo

foo = my_string.count('a')

print(foo == 2)
# Out:
# True

# %%
# create a string called my_string such that this cell prints True

my_string = 'hello world'

print(my_string.endswith('world'))
# Out:
# True

# %%
# create a string called my_string such that this cell prints True

my_string = 'abc'

print(my_string.find('a') == 0)
# Out:
# True

# %%
# create a string called my_string such that this cell prints True

my_string = 'abc'

print(my_string.index('a') == 0)
# Out:
# True

# %%
my_string = '{} world'

# create a new variable foo such that this cell prints True
# use the format method on my_string to create foo

foo = my_string.format('hello')

print(foo == 'hello world')
# Out:
# True

# %%
my_string = 'hello'.join(['a', 'b', 'c'])

# create a new variable foo such that this cell prints True

foo = 'ahellobhelloc'

print(foo == my_string)

# %%
my_string = 'a'

# create a new variable foo such that this cell prints True
# use the `center` method on my_string to create foo

foo = my_string.center(3, 'b')

print(foo == 'bab')
