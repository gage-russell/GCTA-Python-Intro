# %% [raw]
# data types
#     int
#     string
#     float
#     bool
#     None
#
# intro functions (print focus; reading)
#     paraenthesis
#     colon
#     indentation
#     parameters
#     default parameters
#     arguments
#
# built-in functions
#     help
#     type
#     isinstance
#
# io
#     print
#     input
#
# operators
#     assignment operators
#         =
#     arithemetic operators
#         + - * / ** // %
#         uniary
#         binary
#     augmented assignment operators
#         +=  -=  *=  /=  **=  //=  %=
#
# operators
#     boolean
#         and or not
#     comparison
#         == != > < >= <=
#
# ## control flow ##
#
# conditionals
#     if elif else
#
# loops
#     while for break continue
#
# (PCEP imposed)
# operators
#     bitwise
#         & | ^ ~ << >>
#
# (PCEP imposed)
# matrices
#     up to r3
#
# (?position?)
# advanced lists?:
#     list comprehension (Module 3)
#         basic
#         single if statement
#         else if statements
#         show possible nesting?
#     mention dictionary comprehension?
#
# basic data structures:
#     dictionaries
#     tuples
#
# advanced functions
#     review syntax
#     positional arguments
#     keyword arguments
#     default arguments
#   ? adv arguments (pos, / , pos or kw, * , kw)
#         arbitrary positional * arg
#         arbitrary keyword * arg
#     return
#     default return
#
#
#
# to add:
#     scope (good Module coverage I think)
#     exceptions (try except errortype)
#
#
# arguments:
# https://miro.medium.com/max/875/1*wUnUIMdsTwd9QE-ziQfJjA.png

# %%
todo cheatsheet:
    inclusive exclusive
    parapmter argument
    default arguments params etc
